# %%
import cv2
import numpy as np

# %%
img = cv2.imread(r'C:\Users\Tanya srivastava\Downloads\Flower.jpg',1)
cv2.imshow("Hello",img)
cv2.waitKey()
cv2.destroyAllWindows()

R,B,G = img[0,12]
print(R,B,G)
# Out:
# 79 88 75

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("Gray Hello",gray_img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
gray_img[0,0]
# Out:
# 24

# %%
hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
cv2.imshow("Value channel", hsv_img[:,:,2])
cv2.waitKey()
cv2.destroyAllWindows()

# %%
R,B,G = cv2.split(img)
zeros = np.zeros(img.shape[:2],dtype = "uint8")
cv2.imshow("Red", cv2.merge([zeros,zeros,R]))
cv2.waitKey()
cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt

# %%
histogram  = cv2.calcHist([img],[2],None,[256],[0,256])
plt.hist(img.ravel(),256,[0,256]);
plt.show();
color = ('b','g','r')
for i,col in enumerate(color):
    histogram2 = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histogram2, color = col)
    plt.xlim([0,256])
    plt.show()

# %%
square = np.zeros((500,500,3),np.uint8)
cv2.imshow("Square",square)
cv2.waitKey(0)
cv2.destroyAllWindows()
#change into 2d np array for grayscale image

# %%
cv2.line (square,(0,0),(500,500),(255,237,56),6)
cv2.imshow("Square & Line",square)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.circle(square, (250,250),250,(123,255,90),1)
cv2.imshow("SquareLineCircle",square)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
poly = np.array([[12,56],[90,90],[106,200],[500,500]],np.int32)
poly = poly.reshape((-1,1,2))
cv2.polylines(square,[poly],True,(9,90,255),1)
cv2.imshow("Square&Polygon",square)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.putText(square,"HI",(100,90),cv2.FONT_HERSHEY_COMPLEX,3,(255,12,4),9)
cv2.imshow("SquareText",square)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image = cv2.imread(r"C:\Users\Tanya srivastava\Downloads\stars.png",1)
h,w =image.shape[:2]
h_qua = h/4
w_qua = w/4
d_image =image

# %%
T= np.float32([[1,0,h_qua],[0,1,w_qua]])

# %%
img_translation = cv2.warpAffine(image,T,(h,w))
cv2.imshow("Translation",img_translation)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
T
# Out:
# array([[  1.  ,   0.  ,  43.25],
#        [  0.  ,   1.  , 170.  ]], dtype=float32)

# %%
rot_ = cv2.getRotationMatrix2D((w/2,h/2),90,0.5)
rot_img = cv2.warpAffine(image,rot_,(w,h))
cv2.imshow("Rotation",rot_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_sca = cv2.resize(image,None,fx=0.75,fy=1)
cv2.imshow("Linear Inter",img_sca)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
small = cv2.pyrDown(image)
large = cv2.pyrUp(image)
cv2.imshow("Small",small)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imshow("Large",large)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
srow , scol = int(h*0.25),int(w*0.25)
erow , ecol = int(h*0.75),int(w*0.75)
cropped = image[srow:erow,scol:ecol]
cv2.imshow("Cropped",cropped)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
M = np.ones(image.shape, dtype ="uint8")*75
add = cv2.add(image,M)
sub = cv2.subtract(image,M)
cv2.imshow("Add",add)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
kernel_sharpening = np.array([[-1,-1,-1],
                 [-1,9,-1],
                 [-1,-1,-1]])
sharp = cv2.filter2D(image,-1,kernel_sharpening)
cv2.imshow("Sharp",sharp)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
square1 = np.ones((300,300),np.uint8)
cv2.rectangle(square1,(50,50),(250,250),(255,255,254),-6)
cv2.imshow("Sq",square1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
ell = np.zeros((300,300),np.uint8)
cv2.ellipse(ell,(150,150),(150,150),30,0,180,255,-1)
cv2.imshow("Ellipse",ell)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
And = cv2.bitwise_and(square1,ell)
cv2.imshow("AND",And)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
kernel_3 = np.ones((3,3),np.float32)/3
blur = cv2.filter2D(image,-1,kernel_3)
cv2.imshow("Blur",blur)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray_ = cv2.imread(r'C:\Users\Tanya srivastava\Downloads\Flower.jpg',0)
ret,thresh = cv2.threshold(gray_,127,225,cv2.THRESH_BINARY)

# %%
cv2.imshow("Threshold",thresh)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
_,th = cv2.threshold(gray_,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
cv2.imshow("Threshold_OTSU",th)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
text = cv2.imread(r"C:\Users\Tanya srivastava\Downloads\text.jpg",0)
cv2.imshow("Original",text)
cv2.waitKey(0)
cv2.destroyAllWindows()
kernel_5 = np.ones((5,5),np.uint8)
ero = cv2.erode(text,kernel_5,iterations =1)
cv2.imshow("Erosion",ero)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#canny best edge detection
canny = cv2.Canny(image,20,170)
cv2.imshow("Canny",canny)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
contours,hi = cv2.findContours(canny.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
cv2.drawContours(gray_,contours,-1,(255,0,0),3)
cv2.imshow("Contours",gray_)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
blank_ = np.zeros((image.shape[0],image.shape[1],3))
cv2.drawContours(blank_,contours,-1,(255,0,0),3)
cv2.imshow("1-Contours",blank_)
cv2.waitKey(0)
cv2.destroyAllWindows()
print("Number",len(contours))
# Out:
# Number 4

# %%
def get_area(contours):
    all_area=[]
    for c in contours:
        area = cv2.contourArea(cnt)
        all_area.append(area)
    return all_area

# %%
sorted_ = sorted(contours,key=cv2.contourArea,reverse =True)

# %%
for c_ in sorted_:
    cv2.drawContours(d_image,[c_],-1,(255,0,0),3)
    cv2.waitKey(0)
    cv2.imshow("Highlighting",d_image)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image = cv2.imread(r"C:\Users\Tanya srivastava\Downloads\stars.png",1)
d_image=image
def x_cen(countours):
    if cv2.contourArea(contours) > 10:
        cent_ = cv2.moments(contours)
        return (int(cent_['m10']/cent_['m00']))

# %%
def ident_cent(image,centroid):
    cent_ = cv2.moments(centroid)
    c_x = int(cent_["m10"]/cent_["m00"])
    c_y = int(cent_["m01"]/cent_["m00"])
    cv2.circle(d_image,(c_x,c_y),10,(255,0,0),-1)
    return image

# %%
#sorted left to right
for (i,c) in enumerate(contours):
    org = ident_cent(image,c)
    
cv2.imshow("Sorted-3",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

ltor = sorted(contours,key=x_cen,reverse = False)
for (i,c) in enumerate(ltor):
    cv2.drawContours(image.copy(),[c],-1,(255,0,0),3)
    cent_= cv2.moments(c)
    c_x = int(cent_["m10"]/cent_["m00"])
    c_y = int(cent_["m01"]/cent_["m00"])
    cv2.putText(image, str(i+1), (cx, cy),cv2.FONT_HERSHEY_SIMPLEX,1,(255,0,0),3)
    cv2. imshow('6 - Left to Right Contour' ,image)
    (x,y,w,h)= cv2. boundingRect(c)
    cropped_contour = orginal_image[y: y+h, x:x + w]

    image_name = "output_shape_number_" + str(i+1) + ".jpg"
    print( image_name)
    cv2. imwrite(image_name, cropped_contour)

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-2d23408d213a> in <module>
#       7 cv2.destroyAllWindows()
#       8
# ----> 9 ltor = sorted(contours,key=x_cen,reverse = False)
#      10 for (i,c) in enumerate(ltor):
#      11     cv2.drawContours(image.copy(),[c],-1,(255,0,0),3)
#
# <ipython-input-45-89a9d6691cff> in x_cen(countours)
#       2 d_image=image
#       3 def x_cen(countours):
# ----> 4     if cv2.contourArea(contours) > 10:
#       5         cent_ = cv2.moments(contours)
#       6         return (int(cent_['m10']/cent_['m00']))
#
# TypeError: Expected cv::UMat for argument 'contour'
